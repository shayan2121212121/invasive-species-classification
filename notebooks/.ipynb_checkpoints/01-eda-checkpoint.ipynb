# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
import pandas as pd

# File paths
source_file = '/Users/mdshayan/Desktop/invasive-species-classifier/data/metadata/metadata.csv'
destination_file = '/Users/mdshayan/Desktop/invasive-species-classifier/data/metadata/acridotheres_tristis/metadata.csv'

# Load the source and destination CSVs
df_source = pd.read_csv(source_file)
df_dest = pd.read_csv(destination_file)

# Filter entries with scientificName 
df_filtered = df_source[df_source['scientificName'] == 'Acridotheres tristis']

# Append to destination DataFrame
df_combined = pd.concat([df_dest, df_filtered], ignore_index=True)

# Optional: Drop duplicates based on occurrenceID (or any key columns)
df_combined.drop_duplicates(subset='occurrenceID', inplace=True)

# Save back to the destination file
df_combined.to_csv(destination_file, index=False)

print(f"Appended {len(df_filtered)} entries to {destination_file}")
# Out:
# Appended 497 entries to /Users/mdshayan/Desktop/invasive-species-classifier/data/metadata/acridotheres_tristis/metadata.csv
# /var/folders/kw/bqh_f_4j06d1sth30j65r86m0000gn/T/ipykernel_39261/689825713.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_combined = pd.concat([df_dest, df_filtered], ignore_index=True)

# %%
# File path
file_path = '/Users/mdshayan/Desktop/invasive-species-classifier/data/metadata/rhinella_marina/metadata.csv'

# Load the CSV
df = pd.read_csv(file_path)

# Filter out rows where scientificName is 'Vulpes vulpes'
df_cleaned = df[df['scientificName'] != 'Vulpes vulpes']

# Save the cleaned DataFrame back to the same file
df_cleaned.to_csv(file_path, index=False)

# %%
# %matplotlib inline

df_rhinella = pd.read_csv("/Users/mdshayan/Desktop/invasive-species-classifier/data/metadata/rhinella_marina/metadata.csv")
df_vulpes = pd.read_csv("/Users/mdshayan/Desktop/invasive-species-classifier/data/metadata/vulpes_vulpes/metadata.csv")

# Add species column explicitly
df_rhinella["species"] = "Rhinella marina"
df_vulpes["species"] = "Vulpes vulpes"

# Combine both
df = pd.concat([df_rhinella, df_vulpes], ignore_index=True)
df["eventDate"] = pd.to_datetime(df["eventDate"], errors="coerce")
# Out:
# /var/folders/kw/bqh_f_4j06d1sth30j65r86m0000gn/T/ipykernel_33065/3412035935.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["eventDate"] = pd.to_datetime(df["eventDate"], errors="coerce")

# %%
sns.countplot(data=df, x="species", palette="viridis")
plt.title("Number of Images per Species Times")
plt.ylabel("Image Count")
plt.xlabel("Species")
plt.show()
# Out:
# /var/folders/kw/bqh_f_4j06d1sth30j65r86m0000gn/T/ipykernel_33065/913653947.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="species", palette="viridis")

# %%
df["year"] = df["eventDate"].dt.year
sns.histplot(data=df, x="year", hue="species", multiple="stack", bins=20, palette="Set2")
plt.title("Observations Over Years")
plt.xlabel("Year")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
df_geo = df.dropna(subset=["decimalLatitude", "decimalLongitude"])

# Create GeoDataFrame
gdf = gpd.GeoDataFrame(df_geo, geometry=gpd.points_from_xy(df_geo["decimalLongitude"], df_geo["decimalLatitude"]), crs="EPSG:4326")

# Plot map
world = gpd.read_file("/Users/mdshayan/Desktop/invasive-species-classifier/data/shapefiles/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp")

ax = world.plot(figsize=(10, 8), color="whitesmoke", edgecolor="gray")

# Plot species points
gdf.plot(ax=ax, column="species", markersize=10, legend=True, cmap="Set1")

# Set map bounds for Australia
ax.set_xlim(110, 155)   # Longitude range (WA to QLD/NSW)
ax.set_ylim(-45, -10)   # Latitude range (TAS to NT)
plt.title("Geographic Distribution of Observations")
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df, y="dataResourceName", hue="species", palette="pastel")
plt.title("Data Sources by Species")
plt.xlabel("Count times 10")
plt.ylabel("Data Resource")
plt.legend(title="Species")
plt.tight_layout()
plt.show()
